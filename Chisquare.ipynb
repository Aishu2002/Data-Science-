# %%
1. State the Hypotheses:
============================================================================================
1. Null Hypothesis (H₀):

There is no significant association between the type of smart home device (Smart Thermostat or Smart Light) and customer satisfaction level.
In other words, the two variables are independent.

2. Alternative Hypothesis (H₁):

There is a significant association between the type of smart home device and customer satisfaction level.
That means the two variables are not independent.

# %%
#2. Compute the Chi-Square Statistic:
#=============================================
import numpy as np
from scipy.stats import chi2_contingency

data = np.array([
    [50, 70],
    [80, 100],
    [60, 90],
    [30, 50],
    [20, 50]
])

# Perform Chi-Square Test
chi2, p, dof, expected = chi2_contingency(data)

# Display results
print("Chi-Square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-value:", p)
print("Expected Frequencies:\n", expected)
# Out:
# Chi-Square Statistic: 5.638227513227513
# Degrees of Freedom: 4
# P-value: 0.22784371130697179
# Expected Frequencies:
#  [[ 48.  72.]
#  [ 72. 108.]
#  [ 60.  90.]
#  [ 32.  48.]
#  [ 28.  42.]]

# %%
from scipy.stats import chi2

# Reset if 'chi2' was used before
dof = 4
alpha = 0.05

# Compute critical value
critical_value = chi2.ppf(1 - alpha, dof)
print("Critical Value:", critical_value)
# Out:
# Critical Value: 9.487729036781154

# %%
#Since chi-square statistics is lesser than critical value( 5.639 < 9.488) we fail to reject null hypothesis meaning there is no significant association between device 
#type and satisfaction level.
